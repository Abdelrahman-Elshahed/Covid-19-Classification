# %% [markdown]
# # **Model Evaluation Notebook**
#
# This notebook handles:
#
#
#  1. Scaling features
#  2. Training several models
#  3. Comparing models
#  4. Saving the best model

# %% [markdown]
# # Load the data

# %%
import pandas as pd
from Model_Training import fit_classifiers, evaluate_classifiers
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
X_train = pd.read_csv("../data/splitted_data_encoded/X_train.csv")
X_test = pd.read_csv("../data/splitted_data_encoded/X_test.csv")
y_train = pd.read_csv("../data/splitted_data_encoded/y_train.csv")['Reinfection']
y_test = pd.read_csv("../data/splitted_data_encoded/y_test.csv")['Reinfection']

# %% [markdown]
# # Scale the data and train the models

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train models
fitted_models = fit_classifiers(X_train_scaled, y_train)

# Evaluate models
evaluation_df = evaluate_classifiers(fitted_models, X_test_scaled, y_test)

# Show results
print("\n Final Comparison:\n")
print(evaluation_df)
# Out:
# Training Logistic Regression...
#  Done in 0.00s
#
# Training Decision Tree...
#  Done in 0.02s
#
# Training Random Forest...
#  Done in 0.38s
#
# Training SVM...
#  Done in 2.35s
#
# Training KNN...
#  Done in 0.00s
#
# Training Gradient Boosting...
#  Done in 0.41s
#
# Training XGBoost...
#  Done in 0.96s
#
#
# 📊 Evaluating Logistic Regression...
#               precision    recall  f1-score   support
#
#            0       0.91      0.59      0.71       543
#            1       0.10      0.46      0.17        57
#
#     accuracy                           0.57       600
#    macro avg       0.51      0.52      0.44       600
# weighted avg       0.83      0.58      0.66       600
#
# Confusion Matrix:
#  [[319 224]
#  [ 31  26]]
#
# 📊 Evaluating Decision Tree...
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.85       543
#            1       0.09      0.19      0.12        57
#
#     accuracy                           0.74       600
#    macro avg       0.50      0.49      0.48       600
# weighted avg       0.83      0.74      0.78       600
#
# Confusion Matrix:
#  [[431 112]
#  [ 46  11]]
#
# 📊 Evaluating Random Forest...
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       543
#            1       0.11      0.05      0.07        57
#
#     accuracy                           0.87       600
#    macro avg       0.51      0.50      0.50       600
# weighted avg       0.83      0.87      0.85       600
#
# Confusion Matrix:
#  [[519  24]
#  [ 54   3]]
#
# 📊 Evaluating SVM...
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83       543
#            1       0.11      0.26      0.15        57
#
#     accuracy                           0.72       600
#    macro avg       0.51      0.52      0.49       600
# weighted avg       0.83      0.72      0.77       600
#
# Confusion Matrix:
#  [[419 124]
#  [ 42  15]]
#
# 📊 Evaluating KNN...
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.81       543
#            1       0.08      0.23      0.12        57
#
#     accuracy                           0.68       600
#    macro avg       0.49      0.48      0.46       600
# weighted avg       0.82      0.68      0.74       600
#
# Confusion Matrix:
#  [[397 146]
#  [ 44  13]]
#
# 📊 Evaluating Gradient Boosting...
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.84       543
#            1       0.11      0.25      0.15        57
#
#     accuracy                           0.73       600
#    macro avg       0.51      0.52      0.50       600
# weighted avg       0.83      0.73      0.78       600
#
# Confusion Matrix:
#  [[427 116]
#  [ 43  14]]
#
# 📊 Evaluating XGBoost...
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       543
#            1       0.13      0.12      0.13        57
#
#     accuracy                           0.84       600
#    macro avg       0.52      0.52      0.52       600
# weighted avg       0.83      0.84      0.84       600
#
# Confusion Matrix:
#  [[497  46]
#  [ 50   7]]
#
#  Final Comparison:
#
#                      Accuracy  Precision    Recall  F1 Score   ROC AUC
# Model
# Random Forest        0.870000   0.830268  0.870000  0.848533  0.508384
# XGBoost              0.840000   0.834823  0.840000  0.837384  0.564861
# Decision Tree        0.736667   0.826221  0.736667  0.776425  0.493360
# Gradient Boosting    0.735000   0.832433  0.735000  0.777176  0.527802
# SVM                  0.723333   0.832801  0.723333  0.769909  0.534199
# KNN                  0.683333   0.822473  0.683333  0.741689  0.479791
# Logistic Regression  0.575000   0.834723  0.575000  0.662665  0.492940

# %% [markdown]
# # Visualize the comparison between models

# %%
# Set style
sns.set(style="whitegrid")

# Plot multiple metrics
metrics_to_plot = ["Accuracy", "F1 Score", "ROC AUC"]

for metric in metrics_to_plot:
    plt.figure(figsize=(10, 5))
    sns.barplot(data=evaluation_df.reset_index(), x="Model", y=metric, palette="viridis")
    plt.title(f"Model Comparison by {metric}")
    plt.xticks(rotation=45)
    plt.ylim(0, 1)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\noura\AppData\Local\Temp\ipykernel_36156\1449460907.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=evaluation_df.reset_index(), x="Model", y=metric, palette="viridis")
# C:\Users\noura\AppData\Local\Temp\ipykernel_36156\1449460907.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=evaluation_df.reset_index(), x="Model", y=metric, palette="viridis")
# C:\Users\noura\AppData\Local\Temp\ipykernel_36156\1449460907.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=evaluation_df.reset_index(), x="Model", y=metric, palette="viridis")

# %% [markdown]
# # Save the best model

# %%
# Save the best performing model
joblib.dump(fitted_models["Random Forest"], "../models/best_model.pkl")
# Out:
# ['../models/best_model.pkl']
