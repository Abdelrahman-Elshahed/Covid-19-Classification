# %% [markdown]
# # **Data Splitting Notebook**
#
# This notebook handles:
#
#
#  1. Splitting the data to training and testing for the features and the target column
#  2. Handling the unbalanced number of samples for the target column

# %% [markdown]
# # Load Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC

# %%
df = pd.read_csv("../data/Cleaned_Data.csv")
df.head(15)
# Out:
#     Age  Gender       Region Preexisting_Condition COVID_Strain  Symptoms  \
# 0    69    Male  Hovedstaden               Obesity        Delta      Mild
# 1    38    Male     Sjælland                Asthma      XBB.1.5      Mild
# 2    41  Female   Syddanmark          Hypertension         Beta      Mild
# 3    81  Female  Hovedstaden                Asthma        Delta    Severe
# 4    50  Female   Syddanmark        Cardiovascular        Delta      Mild
# 5    66    Male     Sjælland        Cardiovascular      Omicron  Moderate
# 6    76  Female     Sjælland               Obesity      Omicron  Moderate
# 7    77  Female     Sjælland              Diabetes      XBB.1.5  Moderate
# 8    79  Female  Nordjylland          Hypertension      XBB.1.5      Mild
# 9    72  Female     Sjælland        Cardiovascular        Alpha    Severe
# 10   20    Male     Sjælland          Hypertension         Beta    Severe
# 11   56    Male     Sjælland                Asthma        Alpha      Mild
# 12   35  Female     Sjælland                Asthma         Beta    Severe
# 13   70    Male  Hovedstaden          Hypertension        Alpha    Severe
# 14   77    Male   Syddanmark               Obesity      Omicron      Mild
#
#     Severity Hospitalized ICU_Admission Ventilator_Support Recovered  \
# 0   Moderate          Yes            No                 No       Yes
# 1   Moderate           No            No                 No        No
# 2       High          Yes           Yes                Yes        No
# 3       High           No            No                 No       Yes
# 4       High           No            No                 No        No
# 5   Moderate           No            No                 No       Yes
# 6   Critical          Yes           Yes                 No        No
# 7        Low           No            No                 No       Yes
# 8        Low           No            No                 No        No
# 9       High           No            No                 No       Yes
# 10       Low           No            No                 No        No
# 11  Critical           No            No                 No       Yes
# 12      High           No            No                 No        No
# 13  Moderate           No            No                 No       Yes
# 14  Moderate           No            No                 No        No
#
#    Reinfection Vaccination_Status  Doses_Received     Occupation  \
# 0           No                Yes               1     Healthcare
# 1           No                 No               0     Healthcare
# 2           No                Yes               3     Unemployed
# 3          Yes                Yes               1  Office Worker
# 4           No                Yes               2        Student
# 5           No                Yes               3     Healthcare
# 6           No                 No               0     Unemployed
# 7           No                Yes               3         Driver
# 8           No                 No               0     Healthcare
# 9           No                Yes               1     Unemployed
# 10         Yes                 No               0        Teacher
# 11          No                 No               0  Office Worker
# 12          No                 No               0     Healthcare
# 13         Yes                Yes               2        Teacher
# 14          No                 No               0         Driver
#
#    Smoking_Status   BMI Recovery_Classification
# 0           Never  27.7        Delayed Recovery
# 1           Never  21.9        Typical Recovery
# 2           Never  22.7        Delayed Recovery
# 3           Never  27.7        Delayed Recovery
# 4           Never  11.9        Delayed Recovery
# 5           Never  29.8        Delayed Recovery
# 6          Former  22.3        Delayed Recovery
# 7          Former  24.4        Delayed Recovery
# 8          Former  26.1        Typical Recovery
# 9         Current  21.2        Delayed Recovery
# 10          Never  27.1           Fast Recovery
# 11         Former  29.2        Delayed Recovery
# 12          Never  22.0        Delayed Recovery
# 13          Never  29.7        Delayed Recovery
# 14          Never  24.9        Typical Recovery

# %% [markdown]
# # Split Data

# %%
X = df.drop(columns=['Reinfection'])
y = df['Reinfection']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
cat_cols = df.columns.tolist()
cat_cols.remove('Age')
cat_cols.remove('BMI')
cat_cols.remove('Doses_Received')
cat_cols.remove('Reinfection')

sm = SMOTENC(random_state=42, categorical_features=cat_cols)
X_resampled, y_resampled = sm.fit_resample(X_train, y_train)

# %%
print("After SMOTE:", y_resampled.value_counts())
# Out:
# After SMOTE: Reinfection
# No     2172
# Yes    2172
# Name: count, dtype: int64

# %% [markdown]
# # Save the splitted data

# %%
X_resampled.to_csv("../data/splitted_data/X_train.csv", index=False)
y_resampled.to_csv("../data/splitted_data/y_train.csv", index=False)
X_test.to_csv("../data/splitted_data/X_test.csv", index=False)
y_test.to_csv("../data/splitted_data/y_test.csv", index=False)
